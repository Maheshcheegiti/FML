# %% [markdown]
# <a href="https://colab.research.google.com/github/Maheshcheegiti/FML/blob/main/DWDM_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# connecting to google drive for datasets
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Experiment on demonstrating loading a dataset, identifying the dependent and independent variables, and dealing with missing data using Python libraries:
# >Dataset: "Boston Housing" dataset from Scikit-learn library
#
# >Step 1: Loading the dataset to load the Boston Housing dataset we first need to import the required libraries and load the dataset as follows:

# %%
import pandas as pd

# load the dataset
boston = pd.read_csv("/content/drive/MyDrive/datasets-master/BostonHousing.csv")

# convert it into a pandas dataframe
data = pd.DataFrame(boston)

data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# >Step 2: Identifying the dependent and independent variables
# In the Boston Housing dataset, the target variable is the median value of owner-occupied homes in thousands of dollars. The other variables are independent variables that affect the target variable. We can identify the dependent and independent variables as follows:

# %%
# the target variable is 'medv'
target = 'medv'

# dependent varible is 'target'
dependent = data[target]

dependent.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: medv, dtype: float64

# %%
# the independent variables are all the columns except 'target'
independent = data.drop(target, axis = 1)

independent.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %% [markdown]
# > Step 3: Dealing with missing data
#  Next we need to check if there are any missing values in the dataset and handle them appropriately. We can check for missing values using the isnull() function as follows:

# %%
# checking with missing values
missing_values = data.isnull().sum()
missing_values
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# ###Output:
# >This will output the number of missing values in each column. If there are missing values, we can handle
# them using one of several methods. For example, we can remove the rows with missing values, fill in the missing values with the mean or median, or use a more advanced imputation technique.
